# %% [markdown]
# # Real Estate Linear Regression

# %%
# Real sate Dataset

import pandas as pd

x = pd.read_excel(r"C:\Users\suraj tripathi\Desktop\Real estate.xlsx")

# %%
x
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
x.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
x.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
x.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
x.shape
# Out:
# (414, 8)

# %%
import seaborn as sns

# %%
sns.heatmap(x.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
z=x.drop(["No","X1 transaction date"],axis = 1)
z
# Out:
#      X2 house age  X3 distance to the nearest MRT station  \
# 0            32.0                                84.87882
# 1            19.5                               306.59470
# 2            13.3                               561.98450
# 3            13.3                               561.98450
# 4             5.0                               390.56840
# ..            ...                                     ...
# 409          13.7                              4082.01500
# 410           5.6                                90.45606
# 411          18.8                               390.96960
# 412           8.1                               104.81010
# 413           6.5                                90.45606
#
#      X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                                 10     24.98298     121.54024
# 1                                  9     24.98034     121.53951
# 2                                  5     24.98746     121.54391
# ...

# %%
y=x["Y house price of unit area"]
y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %%
len(z)
# Out:
# 414

# %%
from sklearn.model_selection import train_test_split

# %%
z_train,z_test,y_train,y_test = train_test_split(z,y,test_size=0.3)

# %%
y_test.size,y_train.size
# Out:
# (125, 289)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(z_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(z_train, y_train)
# Out:
# 1.0

# %%
model.fit(z_test,y_test)
# Out:
# LinearRegression()

# %%
model.score(z_test,y_test)
# Out:
# 1.0

# %%
x
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
x.isna().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
a=pd.read_excel(r"C:\Users\suraj tripathi\Desktop\Real estate.xlsx")

# %%
a
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
a.isna().sum()
# Out:
# No                                         0
# X1 transaction date                        0
# X2 house age                              16
# X3 distance to the nearest MRT station     0
# X4 number of convenience stores            0
# X5 latitude                                0
# X6 longitude                               0
# Y house price of unit area                 0
# dtype: int64

# %%
np.mean(a["X2 house age"])
# Out:
# 17.545728643216076

# %%
a["X2 house age"].fillna(np.mean(a["X2 house age"]),inplace=True)

# %%
a.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
np.mean(a)
# Out:
# C:\Users\suraj tripathi\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# No                                         207.500000
# X1 transaction date                       2013.148971
# X2 house age                                17.545729
# X3 distance to the nearest MRT station    1083.885689
# X4 number of convenience stores              4.094203
# X5 latitude                                 24.969030
# X6 longitude                               121.533361
# Y house price of unit area                  37.980193
# dtype: float64

# %%
a.var()
# Out:
# No                                        1.431750e+04
# X1 transaction date                       7.950552e-02
# X2 house age                              1.240727e+02
# X3 distance to the nearest MRT station    1.592921e+06
# X4 number of convenience stores           8.676334e+00
# X5 latitude                               1.540130e-04
# X6 longitude                              2.355360e-04
# Y house price of unit area                1.851365e+02
# dtype: float64

# %%
a.corr()
# Out:
#                                               No  X1 transaction date  \
# No                                      1.000000            -0.048658
# X1 transaction date                    -0.048658             1.000000
# X2 house age                           -0.038577             0.033042
# X3 distance to the nearest MRT station -0.013573             0.060880
# X4 number of convenience stores        -0.012699             0.009635
# X5 latitude                            -0.010110             0.035058
# X6 longitude                           -0.011059            -0.041082
# Y house price of unit area             -0.028587             0.087491
#
#                                         X2 house age  \
# No                                         -0.038577
# X1 transaction date                         0.033042
# X2 house age                                1.000000
# X3 distance to the nearest MRT station      0.017437
# X4 number of convenience stores             0.046126
# ...

# %%
a.std()
# Out:
# No                                         119.655756
# X1 transaction date                          0.281967
# X2 house age                                11.138791
# X3 distance to the nearest MRT station    1262.109595
# X4 number of convenience stores              2.945562
# X5 latitude                                  0.012410
# X6 longitude                                 0.015347
# Y house price of unit area                  13.606488
# dtype: float64

# %%
print("min value is :{}".format(np.percentile(a["X2 house age"], 25)))
# Out:
# min value is :9.25

# %%
print(np.percentile(a["X2 house age"], 0))
print(np.percentile(a["X2 house age"], 25))
print(np.percentile(a["X2 house age"], 50))
print(np.percentile(a["X2 house age"], 75))
print(np.percentile(a["X2 house age"], 100))
# Out:
# 0.0
# 9.25
# 16.2
# 27.05
# 43.8

# %%
a
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
a_sd=(a-a.mean())/(a.std())
print(a_sd)
# Out:
#            No  X1 transaction date  X2 house age  \
# 0   -1.725784            -0.822688      1.297652
# 1   -1.717427            -0.822688      0.175447
# 2   -1.709069             1.539289     -0.381166
# 3   -1.700712             1.244928     -0.381166
# 4   -1.692355            -1.120595     -1.126310
# ..        ...                  ...           ...
# 409  1.692355            -0.528327     -0.345255
# 410  1.700712            -1.709316     -1.072444
# 411  1.709069             0.358300      0.112604
# 412  1.717427            -0.528327     -0.848003
# 413  1.725784             1.244928     -0.991645
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                 -0.791537                         2.004982
# 1                                 -0.615866                         1.665488
# 2                                 -0.413515                         0.307513
# ...

# %%
print(a.std())
# Out:
# No                                         119.655756
# X1 transaction date                          0.281967
# X2 house age                                11.138791
# X3 distance to the nearest MRT station    1262.109595
# X4 number of convenience stores              2.945562
# X5 latitude                                  0.012410
# X6 longitude                                 0.015347
# Y house price of unit area                  13.606488
# dtype: float64

# %%
a_sd.std()
# Out:
# No                                        1.0
# X1 transaction date                       1.0
# X2 house age                              1.0
# X3 distance to the nearest MRT station    1.0
# X4 number of convenience stores           1.0
# X5 latitude                               1.0
# X6 longitude                              1.0
# Y house price of unit area                1.0
# dtype: float64
